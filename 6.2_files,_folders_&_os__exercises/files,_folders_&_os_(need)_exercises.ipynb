# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %%
import os, glob, shutil

# %%
glob.glob('os-collaboration-exercise-data') # to check the files
# Out:
# ['os-collaboration-exercise-data']

# %%
glob.glob('os-collaboration-exercise-data/**', recursive = True) #to check the files downloaded
# Out:
# ['os-collaboration-exercise-data/',
#  'os-collaboration-exercise-data/nov-02_melbourne.pdf',
#  'os-collaboration-exercise-data/07-28-dhaka.txt',
#  'os-collaboration-exercise-data/10-16-shanghai.txt',
#  'os-collaboration-exercise-data/10-18-dhaka.txt',
#  'os-collaboration-exercise-data/oct-08_shanghai.png',
#  'os-collaboration-exercise-data/09-18-cairo.txt',
#  'os-collaboration-exercise-data/apr-23_jakarta.pdf',
#  'os-collaboration-exercise-data/apr-21_manila.pdf',
#  'os-collaboration-exercise-data/mar-29_manila.pdf',
#  'os-collaboration-exercise-data/aug-26_shanghai.jpg',
#  'os-collaboration-exercise-data/12-15-melbourne.txt',
#  'os-collaboration-exercise-data/sep-23_cairo.pdf',
#  'os-collaboration-exercise-data/jun-20_manila.png',
#  'os-collaboration-exercise-data/07-09-shanghai.txt',
#  'os-collaboration-exercise-data/jun-08_melbourne.jpg',
#  'os-collaboration-exercise-data/04-05-singapore.txt',
#  'os-collaboration-exercise-data/04-06-cairo.txt',
# ...

# %% [markdown]
# **Task 1 & 2**

# %%
month_to_number = {
    'jan': '01', 'feb': '02', 'mar': '03', 'apr': '04',
    'may': '05', 'jun': '06', 'jul': '07', 'aug': '08',
    'sep': '09', 'oct': '10', 'nov': '11', 'dec': '12'
}

def rename_my_file(old_file_name):
    
    month_abbr, day_city = old_file_name.split('-', 1)  
    day, city_extension = day_city.split('_', 1)       
    
    month_number = month_to_number[month_abbr]         
    
    new_file_name = f"{month_number}-{day}-{city_extension}"
    
    return new_file_name

old_filename = 'oct-08_singapore.txt'
new_filename = rename_my_file(old_filename)
print(new_filename)  

print(rename_my_file("jan-14_tokyo.txt"))
print(rename_my_file("feb-14_tokyo.txt"))
print(rename_my_file("mar-14_tokyo.txt"))
print(rename_my_file("apr-14_tokyo.txt"))
print(rename_my_file("may-14_tokyo.txt"))
print(rename_my_file("jun-14_tokyo.txt"))
print(rename_my_file("jul-14_tokyo.txt"))
print(rename_my_file("aug-14_tokyo.txt"))
print(rename_my_file("sep-14_tokyo.txt"))
print(rename_my_file("oct-14_tokyo.txt"))
print(rename_my_file("nov-14_tokyo.txt"))
print(rename_my_file("dec-14_tokyo.txt"))
# Out:
# 10-08-singapore.txt
# 01-14-tokyo.txt
# 02-14-tokyo.txt
# 03-14-tokyo.txt
# 04-14-tokyo.txt
# 05-14-tokyo.txt
# 06-14-tokyo.txt
# 07-14-tokyo.txt
# 08-14-tokyo.txt
# 09-14-tokyo.txt
# 10-14-tokyo.txt
# 11-14-tokyo.txt
# 12-14-tokyo.txt

# %% [markdown]
# **Task 3**

# %%
# the function defined
def rename_my_file(old_file_name):
    month_to_number = {
        'jan': '01', 'feb': '02', 'mar': '03', 'apr': '04',
        'may': '05', 'jun': '06', 'jul': '07', 'aug': '08',
        'sep': '09', 'oct': '10', 'nov': '11', 'dec': '12'
    }
    # Split the filename into its components
    month_abbr, day_city = old_file_name.split('-', 1)
    day, city_extension = day_city.split('_', 1)
    
    # Convert the month abbreviation to a numerical format
    month_number = month_to_number[month_abbr]
    
    # Reassemble the filename in the desired format
    new_file_name = f"{month_number}-{day}-{city_extension}"
    return new_file_name

# List of filenames to convert
file_list = [
    'oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
    'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
    'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
    'jan-01_tokyo.txt'
]

# Using a for loop to apply the function and print progress
for old_filename in file_list:
    new_filename = rename_my_file(old_filename)
    print(f"{old_filename} ----> {new_filename}")
# Out:
# oct-08_singapore.txt ----> 10-08-singapore.txt
# jul-10_cairo.txt ----> 07-10-cairo.txt
# may-15_dhaka.txt ----> 05-15-dhaka.txt
# may-13_cairo.txt ----> 05-13-cairo.txt
# oct-21_cairo.txt ----> 10-21-cairo.txt
# jan-10_singapore.txt ----> 01-10-singapore.txt
# jun-20_tokyo.txt ----> 06-20-tokyo.txt
# aug-06_jakarta.txt ----> 08-06-jakarta.txt
# dec-21_karachi.txt ----> 12-21-karachi.txt
# jan-01_tokyo.txt ----> 01-01-tokyo.txt

# %%
# Define the path to the folder
folder_path = ''  # Change this to your folder path

# Create the pattern for .txt files
pattern = os.path.join(folder_path, '*.txt')

# Use glob to get all .txt files
txt_files = glob.glob(pattern)

# Print the list of .txt files
print(txt_files)
# Out:
# []

# %% [markdown]
# Task 4

# %%
def rename_my_file(old_filename):
    month_to_number = {
        'jan': '01', 'feb': '02', 'mar': '03', 'apr': '04',
        'may': '05', 'jun': '06', 'jul': '07', 'aug': '08',
        'sep': '09', 'oct': '10', 'nov': '11', 'dec': '12'}

    month_abbr, day_city = old_filename.split('-', 1)
    day, city_extension = day_city.split('_', 1)

    month_number = month_to_number[month_abbr]
    
    new_file_name = f"{month_number}-{day}-{city_extension}"
    return new_file_name

txt_files = glob.glob('os-collaboration-exercise-data/*.txt') #to get all the txt files

# Loop through each .txt file and rename it
for file in txt_files:
    # use split funciton to get the file name from the path, onluy have last part 
    old_filename = file.split('/', 1)
    temp = old_filename[1]
    print(temp)
    old_filename = temp.lstrip("new_new_")
         
    # shaved part to rename function 
    new_name = rename_my_file(old_filename)
    
    # old path and put together 
    new_path = os.path.join(directory, new_name)
    
    os.rename(file, new_path)

# %%
print(txt_files)
# Out:
# ['os-collaboration-exercise-data/07-28-dhaka.txt', 'os-collaboration-exercise-data/10-16-shanghai.txt', 'os-collaboration-exercise-data/10-18-dhaka.txt', 'os-collaboration-exercise-data/09-18-cairo.txt', 'os-collaboration-exercise-data/12-15-melbourne.txt', 'os-collaboration-exercise-data/07-09-shanghai.txt', 'os-collaboration-exercise-data/04-05-singapore.txt', 'os-collaboration-exercise-data/04-06-cairo.txt', 'os-collaboration-exercise-data/05-02-osaka.txt', 'os-collaboration-exercise-data/07-07-osaka.txt', 'os-collaboration-exercise-data/01-01-osaka.txt', 'os-collaboration-exercise-data/10-11-shanghai.txt', 'os-collaboration-exercise-data/08-08-melbourne.txt', 'os-collaboration-exercise-data/10-26-jakarta.txt', 'os-collaboration-exercise-data/08-20-tokyo.txt', 'os-collaboration-exercise-data/03-04-osaka.txt', 'os-collaboration-exercise-data/08-02-jakarta.txt', 'os-collaboration-exercise-data/04-12-singapore.txt', 'os-collaboration-exercise-data/03-06-cairo.txt', 'os-collaboration-
# ...

# %% [markdown]
# **Task 5**

# %%
# Define the list of cities
cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
          'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

# Define the directory containing the files
source_directory = 'os-collaboration-exercise-data/'
destination_directory = 'os-collaboration-exercise-data/'

# Create folders for each city
for city in cities:
    city_folder = os.path.join(destination_directory, city)
    # Check if the folder already exists; if not, create it
    if not os.path.exists(city_folder):
        os.makedirs(city_folder)

# Move files into corresponding folders
for file_name in os.listdir(source_directory):
    # Process only .txt files
    if file_name.endswith('.txt'):
        basename = file_name.split('.')[0]
        if '-' in basename:
            city_name = basename.split('-')[-1]
        
        # Ensure the city name is in the correct format
        city_name = city_name.capitalize()

        # Construct old and new file paths
        old_file_path = os.path.join(source_directory, file_name)
        new_city_folder = os.path.join(destination_directory, city_name)
        new_file_path = os.path.join(new_city_folder, file_name)

        # Move the file to the new folder
        shutil.move(old_file_path, new_file_path)

        # Print progress
        print(f"Moved {file_name} to {city_name} folder.")
# Out:
# Moved 07-28-dhaka.txt to Dhaka folder.
# Moved 10-16-shanghai.txt to Shanghai folder.
# Moved 10-18-dhaka.txt to Dhaka folder.
# Moved 09-18-cairo.txt to Cairo folder.
# Moved 12-15-melbourne.txt to Melbourne folder.
# Moved 07-09-shanghai.txt to Shanghai folder.
# Moved 04-05-singapore.txt to Singapore folder.
# Moved 04-06-cairo.txt to Cairo folder.
# Moved 05-02-osaka.txt to Osaka folder.
# Moved 07-07-osaka.txt to Osaka folder.
# Moved 01-01-osaka.txt to Osaka folder.
# Moved 10-11-shanghai.txt to Shanghai folder.
# Moved 08-08-melbourne.txt to Melbourne folder.
# Moved 10-26-jakarta.txt to Jakarta folder.
# Moved 08-20-tokyo.txt to Tokyo folder.
# Moved 03-04-osaka.txt to Osaka folder.
# Moved 08-02-jakarta.txt to Jakarta folder.
# Moved 04-12-singapore.txt to Singapore folder.
# Moved 03-06-cairo.txt to Cairo folder.
# Moved 01-10-shanghai.txt to Shanghai folder.
# Moved 01-03-cairo.txt to Cairo folder.
# Moved 12-02-melbourne.txt to Melbourne folder.
# ...

# %% [markdown]
# **Task 6**

# %%
# Define the source directory and destination directory
source_directory = 'os-collaboration-exercise-data/'
destination_directory = 'os-collaboration-exercise-data/'

# Define the Cairo folder
cairo_folder = os.path.join(destination_directory, 'Cairo')

# Create the Cairo folder if it does not exist
if not os.path.exists(cairo_folder):
    os.makedirs(cairo_folder)

# Use glob to list all files related to Cairo
cairo_files = glob.glob(os.path.join(source_directory, '*cairo*'))

# Copy each Cairo file to the Cairo folder
for file_path in cairo_files:
    # Extract the filename from the path
    file_name = os.path.basename(file_path)
    
    # Define the new path in the Cairo folder
    new_file_path = os.path.join(cairo_folder, file_name)
    
    # Copy the file to the new location
    shutil.copy(file_path, new_file_path)
    
    # Print progress
    print(f"Copied {file_name} to Cairo folder.")
# Out:
# Copied sep-23_cairo.pdf to Cairo folder.
# Copied jan-12_cairo.pdf to Cairo folder.
# Copied mar-05_cairo.pdf to Cairo folder.
# Copied may-25_cairo.png to Cairo folder.
# Copied jul-27_cairo.png to Cairo folder.
# Copied dec-07_cairo.jpg to Cairo folder.
# Copied mar-24_cairo.pdf to Cairo folder.
# Copied sep-16_cairo.png to Cairo folder.
# Copied jan-27_cairo.jpg to Cairo folder.
# Copied sep-02_cairo.png to Cairo folder.
# Copied dec-13_cairo.pdf to Cairo folder.
# Copied nov-14_cairo.pdf to Cairo folder.
# Copied aug-12_cairo.jpg to Cairo folder.
# Copied apr-10_cairo.png to Cairo folder.
# Copied dec-26_cairo.pdf to Cairo folder.
# Copied nov-19_cairo.jpg to Cairo folder.
# Copied nov-21_cairo.pdf to Cairo folder.
# Copied mar-05_cairo.png to Cairo folder.
# Copied sep-28_cairo.jpg to Cairo folder.
# Copied may-02_cairo.png to Cairo folder.
# Copied sep-28_cairo.png to Cairo folder.
# Copied dec-01_cairo.jpg to Cairo folder.
# Copied jul-14_cairo.jpg to Cairo folder.
# ...

# %% [markdown]
# **Task 7**

# %%
# Define the source directory and destination directory
source_directory = 'os-collaboration-exercise-data/'
destination_directory = 'os-collaboration-exercise-data/'

# List of cities
cities = [ 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
          'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

# Create a folder for each city if it does not exist
for city in cities:
    city_folder = os.path.join(destination_directory, city)
    if not os.path.exists(city_folder):
        os.makedirs(city_folder)

# Copy files for each city into their respective folders
for city in cities:
    # Use glob to list all files related to the current city
    city_files = glob.glob(os.path.join(source_directory, f'*{city.lower()}*'))
    
    # Copy each city file to the respective city folder
    for file_path in city_files:
        # Extract the filename from the path
        file_name = os.path.basename(file_path)
        
        # Define the new path in the city folder
        new_file_path = os.path.join(destination_directory, city, file_name)
        
        # Copy the file to the new location
        shutil.copy(file_path, new_file_path)
        
        # Print progress
        print(f"Copied {file_name} to {city} folder.")
# Out:
# Copied sep-23_cairo.pdf to Cairo folder.
# Copied jan-12_cairo.pdf to Cairo folder.
# Copied mar-05_cairo.pdf to Cairo folder.
# Copied may-25_cairo.png to Cairo folder.
# Copied jul-27_cairo.png to Cairo folder.
# Copied dec-07_cairo.jpg to Cairo folder.
# Copied mar-24_cairo.pdf to Cairo folder.
# Copied sep-16_cairo.png to Cairo folder.
# Copied jan-27_cairo.jpg to Cairo folder.
# Copied sep-02_cairo.png to Cairo folder.
# Copied dec-13_cairo.pdf to Cairo folder.
# Copied nov-14_cairo.pdf to Cairo folder.
# Copied aug-12_cairo.jpg to Cairo folder.
# Copied apr-10_cairo.png to Cairo folder.
# Copied dec-26_cairo.pdf to Cairo folder.
# Copied nov-19_cairo.jpg to Cairo folder.
# Copied nov-21_cairo.pdf to Cairo folder.
# Copied mar-05_cairo.png to Cairo folder.
# Copied sep-28_cairo.jpg to Cairo folder.
# Copied may-02_cairo.png to Cairo folder.
# Copied sep-28_cairo.png to Cairo folder.
# Copied dec-01_cairo.jpg to Cairo folder.
# Copied jul-14_cairo.jpg to Cairo folder.
# ...
